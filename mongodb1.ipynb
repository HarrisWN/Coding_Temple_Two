# %%
import pandas as pd
import plotly.express as px
import sqlalchemy
import pymongo

# %%
matdf = pd.read_csv(r'/Users/burnesbrown1/Documents/Coding Temple/Coding_Temple_Two/MongoDB/student+performance/student/student-mat.csv', delimiter =";")
matdf

pordf = pd.read_csv('/Users/burnesbrown1/Documents/Coding Temple/Coding_Temple_Two/MongoDB/student+performance/student/student-por.csv', delimiter =";")
pordf
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# View the data

# %%
matdf.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Format column names

# %%
matdf.columns = matdf.columns.str.lower()
matdf.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'pstatus', 'medu', 'fedu',
#        'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'dalc',
#        'walc', 'health', 'absences', 'g1', 'g2', 'g3'],
#       dtype='object')

# %%
matdf.rename(columns={'famsize':'fam_size','medu':'m_edu','pedu':'p_edu','mjob':'m_job','fedu':'f_edu','traveltime':'travel_time','studytime':'study_time',
                   'schoolsup':'schools_sup','famsup':'fam_sup','famrel':'fam_rel','freetime':'free_time','goout':'go_out',
                    'g1':'g_1','g2':'g_2','g3':'g_3','dalc':'d_alc','walc':'w_alc','fjob':'f_job','pstatus':'p_status'}, inplace= True)
matdf.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'fam_size', 'p_status', 'm_edu',
#        'f_edu', 'm_job', 'f_job', 'reason', 'guardian', 'travel_time',
#        'study_time', 'failures', 'schools_sup', 'fam_sup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'fam_rel',
#        'free_time', 'go_out', 'd_alc', 'w_alc', 'health', 'absences', 'g_1',
#        'g_2', 'g_3'],
#       dtype='object')

# %% [markdown]
# View object types

# %%
matdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school       395 non-null    object
#  1   sex          395 non-null    object
#  2   age          395 non-null    int64
#  3   address      395 non-null    object
#  4   fam_size     395 non-null    object
#  5   p_status     395 non-null    object
#  6   m_edu        395 non-null    int64
#  7   f_edu        395 non-null    int64
#  8   m_job        395 non-null    object
#  9   f_job        395 non-null    object
#  10  reason       395 non-null    object
#  11  guardian     395 non-null    object
#  12  travel_time  395 non-null    int64
#  13  study_time   395 non-null    int64
#  14  failures     395 non-null    int64
#  15  schools_sup  395 non-null    object
#  16  fam_sup      395 non-null    object
#  17  paid         395 non-null    object
# ...

# %% [markdown]
# Clean second dataframe

# %%
pordf.columns = pordf.columns.str.lower()
pordf.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'pstatus', 'medu', 'fedu',
#        'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'dalc',
#        'walc', 'health', 'absences', 'g1', 'g2', 'g3'],
#       dtype='object')

# %%
pordf.rename(columns={'famsize':'fam_size','medu':'m_edu','pedu':'p_edu','mjob':'m_job','fedu':'f_edu','traveltime':'travel_time','studytime':'study_time',
                   'schoolsup':'schools_sup','famsup':'fam_sup','famrel':'fam_rel','freetime':'free_time','goout':'go_out',
                    'g1':'g_1','g2':'g_2','g3':'g_3','dalc':'d_alc','walc':'w_alc','fjob':'f_job','pstatus':'p_status'}, inplace= True)
pordf.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'fam_size', 'p_status', 'm_edu',
#        'f_edu', 'm_job', 'f_job', 'reason', 'guardian', 'travel_time',
#        'study_time', 'failures', 'schools_sup', 'fam_sup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'fam_rel',
#        'free_time', 'go_out', 'd_alc', 'w_alc', 'health', 'absences', 'g_1',
#        'g_2', 'g_3'],
#       dtype='object')

# %%
pordf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school       649 non-null    object
#  1   sex          649 non-null    object
#  2   age          649 non-null    int64
#  3   address      649 non-null    object
#  4   fam_size     649 non-null    object
#  5   p_status     649 non-null    object
#  6   m_edu        649 non-null    int64
#  7   f_edu        649 non-null    int64
#  8   m_job        649 non-null    object
#  9   f_job        649 non-null    object
#  10  reason       649 non-null    object
#  11  guardian     649 non-null    object
#  12  travel_time  649 non-null    int64
#  13  study_time   649 non-null    int64
#  14  failures     649 non-null    int64
#  15  schools_sup  649 non-null    object
#  16  fam_sup      649 non-null    object
#  17  paid         649 non-null    object
# ...

# %%
totaldf = [matdf, pordf]

student_performance = pd.concat(totaldf)

student_performance
# Out:
#     school sex  age address fam_size p_status  m_edu  f_edu     m_job  \
# 0       GP   F   18       U      GT3        A      4      4   at_home
# 1       GP   F   17       U      GT3        T      1      1   at_home
# 2       GP   F   15       U      LE3        T      1      1   at_home
# 3       GP   F   15       U      GT3        T      4      2    health
# 4       GP   F   16       U      GT3        T      3      3     other
# ..     ...  ..  ...     ...      ...      ...    ...    ...       ...
# 644     MS   F   19       R      GT3        T      2      3  services
# 645     MS   F   18       U      LE3        T      3      1   teacher
# 646     MS   F   18       U      GT3        T      1      1     other
# 647     MS   M   17       U      LE3        T      3      1  services
# 648     MS   M   18       R      LE3        T      3      2  services
#
#         f_job  ... fam_rel free_time  go_out  d_alc  w_alc health absences  \
# ...

# %%
student_performance.to_csv('student_per.csv', index=False)

# %%
con_str = 'mongodb+srv://harriswn:WhitneyB@records.qcyrqlm.mongodb.net/?retryWrites=true&w=majority'
import pymongo
client = pymongo.MongoClient(con_str)

# %%
db = client.db
mongodb = db.mongodb

# %%
mongodb.insert_many(df.to_dict(orient="records"))
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /Users/burnesbrown1/Documents/Coding Temple/Coding_Temple_Two/MongoDB/student+performance/student/mongodb1.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/Users/burnesbrown1/Documents/Coding%20Temple/Coding_Temple_Two/MongoDB/student%2Bperformance/student/mongodb1.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> mongodb.insert_many(df.to_dict(orient="records"))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# ...
